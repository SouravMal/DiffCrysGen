# %% [markdown]
# # DiffCrysGen Demo Notebook
#
# This notebook demonstrates how to use the DiffCrysGen library to generate and analyze inorganic crystal structures using our pre-trained score-based diffusion model.

# %% [markdown]
# ## Importing the libraries

# %%
from diffcrysgen.sampler import generate_samples
import numpy as np

# %% [markdown]
# ## Generate Samples

# %%
samples = generate_samples(num_samples=10)
np.save("generated_ircr.npy", samples)
# Out:
# Scaler loaded.
# Using device: cpu
# Model loaded from: assets/saved-model/sdm.pt
# Sampling batch 1/1 done.
# Total sampling time: 0.07 minutes
# Generated IRCR shape: (10, 136, 3)

# %% [markdown]
# ## Analyze Generated Samples

# %%
from diffcrysgen.analyze_generated_structures import analyze_ircr_data

df = analyze_ircr_data(generated_ircr_path="generated_ircr.npy",save_cifs=True)

df
# Out:
# Loaded 10 materials from generated_ircr.npy
# Saved extracted data to: generated_material_data.csv
#         ID    Formula     type  Natoms  min-pairwise-distance  Zmax  \
# 0   smps-1  Mg3Ru3Zn6  ternary      12                 1.9227    44
# 1   smps-2   Cd4Tm2Y4  ternary      10                 2.9982    69
# 2   smps-3   Hf4N4Ni2  ternary      10                 1.2213    72
# 3   smps-4      CePt6   binary       7                 2.8270    78
# 4   smps-5  Al4Hg4Pu2  ternary      10                 2.4416    94
# 5   smps-6       NpSn   binary       2                 5.2947    93
# 6   smps-7      Pd2Pm   binary       3                 2.9802    61
# 7   smps-8  Co6Hf3Pu3  ternary      12                 2.1457    94
# 8   smps-9   Ag2MoNe6  ternary       9                 0.7114    47
# 9  smps-10  La2Y4Zn10  ternary      16                 2.9872    57
#
#   SPG-symbol  SPG-number validity         a         b          c       alpha  \
# 0         P1           1    valid  3.437753  3.268489  18.347414   89.774609
# 1         Pm           6    valid  3.730805  5.016188  14.430185   89.889654
# 2         Pm           6    valid  8.817293  2.953327   5.846629   90.108701
# 3       Pmm2          25    valid  4.041816  4.159912   8.223278   89.977666
# 4         Pm           6    valid  4.180844  4.074026  13.090405   90.000088
# 5         Pm           6    valid  4.150312  4.551094   3.292989   90.081947
# 6     P4/mmm         123    valid  4.690297  4.789615   3.695249   90.002583
# 7         Cm           8    valid  3.755986  3.717585  16.190109   90.040685
# 8         P1           1    valid  4.710290  7.335707   8.781733  115.450370
# 9       Pmm2          25    valid  4.893445  4.819889  15.906079   89.951023
#
#          beta       gamma
# 0   89.924145  119.566608
# 1   98.020883   89.767581
# 2  103.390818   89.917374
# 3   90.050323   90.032162
# 4   89.973257   90.076622
# 5   89.574333  120.108126
# 6   90.121521   89.892089
# 7   89.607330  119.622035
# 8   98.353288  103.065042
# 9   90.047510   89.806393
