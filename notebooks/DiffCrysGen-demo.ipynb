# %% [markdown]
# # DiffCrysGen Demo Notebook
#
# This notebook demonstrates how to use the DiffCrysGen library to generate and analyze inorganic crystal structures using our pre-trained score-based diffusion model.

# %% [markdown]
# ## Importing the libraries

# %%
from diffcrysgen.sampler import generate_samples
import numpy as np

# %% [markdown]
# ## Generate Samples

# %%
samples = generate_samples(num_samples=10)
np.save("generated_ircr.npy", samples)
# Out:
# Scaler loaded.
# Using device: cpu
# Model loaded from: assets/saved-model/sdm.pt
# Sampling batch 1/1 done.
# Total sampling time: 0.07 minutes
# Generated IRCR shape: (10, 136, 3)

# %% [markdown]
# ## Analyze Generated Samples

# %%
from diffcrysgen.analyze_generated_structures import analyze_ircr_data

df = analyze_ircr_data(generated_ircr_path="generated_ircr.npy",save_cifs=True)

df
# Out:
# Loaded 10 materials from generated_ircr.npy
# Saved extracted data to: generated_material_data.csv
#         ID     Formula     type  Natoms  min-pairwise-distance  Zmax  \
# 0   smps-1     AuLaTb2  ternary       4                 3.3030    79
# 1   smps-2     AuGaGd2  ternary       4                 2.9534    79
# 2   smps-3    Na5O12V2  ternary      19                 0.6160    23
# 3   smps-4  Al4Dy4Er10  ternary      18                 1.4206    68
# 4   smps-5     MgMn2Si  ternary       4                 2.5803    25
# 5   smps-6      Ce8Si4   binary      12                 1.6479    58
# 6   smps-7     Co6HgPu  ternary       8                 1.4106    94
# 7   smps-8      H4AcDy  ternary       6                 1.8719    89
# 8   smps-9   Ir8Ni2Os6  ternary      16                 0.0135    77
# 9  smps-10   Fe3Te3Ti6  ternary      12                 1.1736    52
#
#   SPG-symbol  SPG-number validity         a          b          c       alpha  \
# 0       Pmmm          47    valid  4.922560   5.173776   4.438328   89.941739
# 1       Pmm2          25    valid  3.810379   3.521864   6.901535   89.973306
# 2         P1           1    valid  6.293008   6.723632   6.778259  111.889943
# 3         P1           1    valid  4.353772  24.485536   4.703899   90.085252
# 4     P4/mmm         123    valid  2.994593   2.925114   6.037689   90.072400
# 5         P1           1    valid  4.180237   7.320252  11.273629   89.892548
# 6       Pmm2          25    valid  4.640442   4.442255   6.269790   89.958733
# 7         Pm           6    valid  3.593235   3.615863   5.802221   89.958068
# 8       Pmm2          25  invalid  3.895877   3.823299  16.084553   90.032622
# 9         P1           1    valid  3.508087   3.638623  17.783730   89.903407
#
#         beta       gamma
# 0  90.105401   90.015877
# 1  89.913473   89.983791
# 2  85.446949   90.754854
# 3  89.340040   90.094543
# 4  90.175742   89.920601
# 5  89.445346   90.101789
# 6  89.740148   89.894327
# 7  90.206017   89.913638
# 8  89.809436   89.732138
# 9  90.133974  118.838416

# %% [markdown]
# ## Check the number of trainable parameters

# %%
from diffcrysgen.model import Model, UNet

denoise_fn = UNet(in_c=3, out_c=3, time_emb_dim=256)
model = Model(denoise_fn = denoise_fn)

# To calculate the number of trainable parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

num_params = count_parameters(model)
print(f"Number of trainable parameters: {num_params / 1e6:.3f} million")
# Out:
# Number of trainable parameters: 1.322 million

# %%
import ase.io as aio
from ase.visualize import view

atoms = aio.read("./cif-files/valid/smps-5.cif")
print(atoms)
view(atoms, viewer='x3d')
# Out:
# Atoms(symbols='MgMn2Si', pbc=True, cell=[[2.9945932241620796, 0.0, 0.0], [0.004053558440309114, 2.9251110552416133, 0.0], [-0.01851921921618739, -0.007603670609624039, 6.037656091930738]], spacegroup_kinds=...)
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 12.075312183861476">
#     <group/>
#   </viewpoint>
#   <transform translation="-1.4972966120810398 -1.4625555276208067 -3.018828045965369">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 2.9945932241620796 0.0 0.0 2.9986467826023886 2.9251110552416133 0.0 0.004053558440309114 2.9251110552416133 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="-0.01851921921618739 -0.007603670609624039 6.037656091930738">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 2.9945932241620796 0.0 0.0 2.9986467826023886 2.9251110552416133 0.0 0.004053558440309114 2.9251110552416133 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 2.9945932241620796 0.0 0.0 2.9760740049458922 -0.007603670609624039 6.037656091930738 -0.01851921921618739 -0.007603670609624039 6.037656091930738 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.004053558440309114 2.9251110552416133 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 2.9945932241620796 0.0 0.0 2.9760740049458922 -0.007603670609624039 6.037656091930738 -0.01851921921618739 -0.007603670609624039 6.037656091930738 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="1.4818317125175213 1.4650641713467953 2.976650838249525">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.541 1.0 0.0"/>
#             </appearance>
#             <sphere radius="1.41"/>
#           </shape>
#         </transform>
#         <transform translation="2.984379870457874 2.9173710573220433 4.528074098530261">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.612 0.478 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="2.989330603615094 -0.0013732536767824878 1.415348249848843">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.612 0.478 0.78"/>
#             </appearance>
#             <sphere radius="1.39"/>
#           </shape>
#         </transform>
#         <transform translation="1.479118055097787 1.4549482561847473 6.029303814637673">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#       </group>
#     </group>
#   </transform>
# </scene>
# <!--End of Inserted Scene-->
#
#         </X3D>
#     </body>
# </html>
